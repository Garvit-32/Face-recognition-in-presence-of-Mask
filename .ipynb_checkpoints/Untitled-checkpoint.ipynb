# %%
import torch
import os
import numpy as np
from fastai.vision import *
from fastai.metrics import error_rate,accuracy
from tqdm import tqdm
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
torch.device('cuda')
torch.cuda.empty_cache()

# imagePaths = []

dataset_path = 'dataset_with_mask'

# %%
np.random.seed(42)

trfm = get_transforms(do_flip=True, flip_vert=True, max_zoom=1.2, max_rotate=20.0, max_lighting=0.4)

data = ImageDataBunch.from_folder(dataset_path,train='.',valid_pct =0.2,num_workers = 4,bs=16).normalize(imagenet_stats)
# ,ds_tfms = trfm

learn = cnn_learner(data,models.vgg16_bn,metrics = [error_rate,accuracy],callback_fns=ShowGraph)

data.classes
# Out:
# ['angela_merkel',
#  'anushka_sharma',
#  'donald_trump',
#  'narendra_modi',
#  'salman_khan',
#  'shushant_singh_rajput',
#  'vladimir_putin']

# %%
learn.fit_one_cycle(6, max_lr =[1e-6, 1e-4, 1e-3])
# , max_lr =[1e-6, 1e-4, 1e-3]
learn.save('vgg16_bn')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.964096</td>
#       <td>1.425772</td>
#       <td>0.510638</td>
#       <td>0.489362</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.845943</td>
#       <td>0.526884</td>
#       <td>0.127660</td>
#       <td>0.872340</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.152895</td>
#       <td>0.413882</td>
#       <td>0.085106</td>
#       <td>0.914894</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.771654</td>
#       <td>0.373437</td>
#       <td>0.095745</td>
#       <td>0.904255</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.555179</td>
#       <td>0.583791</td>
#       <td>0.106383</td>
#       <td>0.893617</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.436611</td>
#       <td>0.427678</td>
#       <td>0.095745</td>
#       <td>0.904255</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# interp.plot_top_losses(9, figsize=(15,11))
interp.plot_confusion_matrix()

# %%
img = open_image('test_data1/photo.jpg')
# (image.jpg is any random image.)
img.show(figsize=(3, 3))
learn.predict(img)
# Out:
# (Category tensor(5),
#  tensor(5),
#  tensor([0.1760, 0.0065, 0.0386, 0.2555, 0.2143, 0.3075, 0.0016]))

# %%
    learn.export()
